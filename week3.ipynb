# %% [markdown]
# <a href="https://colab.research.google.com/github/Afvanie/PCVK_Genap_2023/blob/main/week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#accessing my google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK/Kucing2.tiff',img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150), color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
tinggi = black_img.shape[0]
lebar = black_img.shape[1]
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
for x in range (tinggi):
  black_img[x, int(x*(lebar/tinggi))] = [255,255,255]
cv2_imshow(black_img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F5D6AC647F0>

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **TUGAS**

# %%
#green-blue
import cv2
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg')
img[:,:,2] = np.zeros([img.shape[0], img.shape[1]])
plt.imshow(img)

# %%
#red-blue
img = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg')
img_rb = img
b,g,r = cv.split(img)
img_rb = cv.merge((b,g*0,b))
plt.imshow(img_rb)

# %%
#baris ke 20-115, kolom 25-120!
img = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg')
plt.imshow(img[20:115,25:120])

# %%
#bairs ke5-30, semua kolom, channel Red
img = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg')
plt.imshow(img[5:30], cmap='Reds')

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg')

cv.rectangle(img,pt1=(200,100),pt2=(500,400),color=(0,255,255),thickness=5)
cv.rectangle(img,pt1=(300,100),pt2=(500,500),color=(255,255,0),thickness=5)
cv.rectangle(img,pt1=(600,500),pt2=(450,200),color=(0,255,0),thickness=5)
cv.rectangle(img,pt1=(450,200),pt2=(600,400),color=(255,0,0),thickness=5)
cv.rectangle(img,pt1=(384,0),pt2=(510,150),color=(0,0,255),thickness=5)

plt.imshow(img)

# %%
img = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg')
cv.rectangle(img,pt1=(200,170),pt2=(360,330),color=(0,255,255),thickness=5)
cv.circle(img,center=(280,250),radius=70,color=(255,0,0),thickness=5)
plt.imshow(img)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img,pt1=(200,170),pt2=(360,330),color=(0,255,255),thickness=5)
cv.circle(img,center=(280,250),radius=70,color=(255,0,0),thickness=5)
cv.rectangle(img,pt1=(0,400),pt2=(50,450),color=(0,0,255),thickness=5)
plt.imshow(img)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/Kucing.jpeg')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img,pt1=(200,170),pt2=(360,330),color=(0,255,255),thickness=5)
cv.circle(img,center=(280,250),radius=70,color=(255,0,0),thickness=5)
cv.rectangle(img,pt1=(0,380),pt2=(80,450),color=(0,0,255),thickness=5)
cv.putText(img,text='Halo',org=(8,430),fontFace=font,fontScale=1,color=(255,255,0),thickness=2, lineType=cv.LINE_AA)
plt.imshow(img)
